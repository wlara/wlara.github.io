# %% [markdown]
# # Chapter 12 Introduction to Python

# %% [markdown]
# ## Variable, Assignment, Basic Output of Text and Variable

# %%
wage = 20 
# assignment # variable

hours = 40
weeks = 52
salary = wage * hours * weeks 
# arithmetic computation

print('Salary is:', salary) 
# print(): direct value, variable # string

hours = 35
# the variable hours is assigned a different value

salary = wage * hours * weeks
print('New salary is:', salary)
# Out:
# Salary is: 41600
# New salary is: 5200

# %% [markdown]
# ## Escape Sequence, Print the Same Line

# %%
wage = 400

print('Your daily wage is $', wage)


weekly_wage = 2000

print('$', wage, 'per day is $', weekly_wage, 'per week') 
# print() multiple variables, multiple values

print('Name\tJob\n------------------') # escape sequence: \n, \t, \\

print('Ann\tDeveloper\nJoe\tInfluencer')

print('Enter name of best friend:', end = '') 
print('Dave.')
# Normally, print() adds a newline character (\n) after the output, causing the cursor to move to the next line.
# When you specify end=' ', it replaces the default newline with a single space (' '), so the cursor stays on the same line, 
# leaving a space after the output instead of moving to the next line.
# Out:
# Your daily wage is $ 400
# $ 400 per day is $ 2000 per week
# Name	Job
# ------------------
# Ann	Developer
# Joe	Influencer
# Enter name of best friend:Dave.

# %% [markdown]
# ## Input, Input wih Prompt

# %%
best_friend = input() # basic input # assignment
print('My best friend is', best_friend)

hours = 40
weeks = 52
hourly_wage = int(input('Enter hourly wage: '))
# input prompt
# int(): cast input object type as int

print('Salary is', hourly_wage * hours * weeks)
# Out:
#  Pei
# My best friend is Pei
# Enter hourly wage:  100
# Salary is 208000

# %% [markdown]
# ## Computation
# Computation can be nested directly inside of a print() statement

# %%
hourly_wage = 20

AnnualSalary = hourly_wage * 40 * 50
print('Annual Salary (from variable) is: ', AnnualSalary)
print('Annual salary (from direct computation is: ', end = "")
print(hourly_wage * 40 * 50) # computation within print()
print() #new line
# Out:
# Annual Salary (from variable) is:  40000
# Annual salary (from direct computation is: 40000
